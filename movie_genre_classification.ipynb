# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from scipy.sparse import hstack

# %%
df = pd.read_csv('tmdb_5000_movies.csv')

# %%
# Check for null values
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Drop rows with missing values in 'genres' column
df = df.dropna(subset=['genres'])

# %%
# Fill missing values in 'overview' column with an empty string
df['overview'] = df['overview'].fillna('')

# %%
# Convert genres from JSON string to list of genre names
import ast

def parse_genres(genre_str):
    try:
        genres_list = ast.literal_eval(genre_str)
        return [genre['name'] for genre in genres_list]
    except:
        return []

df['genres'] = df['genres'].apply(parse_genres)

# %%
# Create a list of unique genres
all_genres = set()
for genres in df['genres']:
    all_genres.update(genres)
all_genres = list(all_genres)

# %%
# Create binary columns for each genre
for genre in all_genres:
    df[genre] = df['genres'].apply(lambda x: 1 if genre in x else 0)

# %%
# Feature and target variables
X = df[['original_title', 'overview']]
y = df[all_genres]

# %%
# Text vectorization
vectorizer_title = TfidfVectorizer(stop_words='english')
vectorizer_overview = TfidfVectorizer(stop_words='english')

# %%
# Fit and transform text data
X_title = vectorizer_title.fit_transform(X['original_title'])
X_overview = vectorizer_overview.fit_transform(X['overview'])

# %%
# Combine title and overview features
X_combined = hstack([X_title, X_overview])

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.3, random_state=42)

# %%
# Train a separate classifier for each genre
classifiers = {}
for genre in all_genres:
    clf = LogisticRegression(max_iter=1000)
    clf.fit(X_train, y_train[genre])
    classifiers[genre] = clf

# %%
# Make predictions
y_pred = pd.DataFrame()
for genre, clf in classifiers.items():
    y_pred[genre] = clf.predict(X_test)

# %%
# Evaluate the model
print("Classification Report:")
for genre in all_genres:
    print(f"\nGenre: {genre}")
    print(classification_report(y_test[genre], y_pred[genre]))
# Out:
# Classification Report:
#
# Genre: Animation
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1384
#            1       0.00      0.00      0.00        57
#
#     accuracy                           0.96      1441
#    macro avg       0.48      0.50      0.49      1441
# weighted avg       0.92      0.96      0.94      1441
#
#
# Genre: Documentary
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1407
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.98      1441
#    macro avg       0.49      0.50      0.49      1441
# weighted avg       0.95      0.98      0.96      1441
#
#
# Genre: Foreign
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1430
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.99      1441
#    macro avg       0.50      0.50      0.50      1441
# weighted avg       0.98      0.99      0.99      1441
#
#
# Genre: History
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1390
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.96      1441
#    macro avg       0.48      0.50      0.49      1441
# weighted avg       0.93      0.96      0.95      1441
#
#
# Genre: Thriller
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85      1045
#            1       0.82      0.10      0.18       396
#
#     accuracy                           0.75      1441
#    macro avg       0.78      0.55      0.52      1441
# weighted avg       0.77      0.75      0.67      1441
#
#
# Genre: Adventure
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      1201
#            1       0.82      0.04      0.07       240
#
#     accuracy                           0.84      1441
#    macro avg       0.83      0.52      0.49      1441
# weighted avg       0.84      0.84      0.77      1441
#
#
# Genre: Mystery
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      1338
#            1       0.00      0.00      0.00       103
#
#     accuracy                           0.93      1441
#    macro avg       0.46      0.50      0.48      1441
# weighted avg       0.86      0.93      0.89      1441
#
#
# Genre: Action
#               precision    recall  f1-score   support
#
#            0       0.77      0.99      0.87      1077
#            1       0.87      0.15      0.25       364
#
#     accuracy                           0.78      1441
#    macro avg       0.82      0.57      0.56      1441
# weighted avg       0.80      0.78      0.71      1441
#
#
# Genre: Family
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1300
#            1       0.00      0.00      0.00       141
#
#     accuracy                           0.90      1441
#    macro avg       0.45      0.50      0.47      1441
# weighted avg       0.81      0.90      0.86      1441
#
#
# Genre: Drama
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71       762
#            1       0.68      0.65      0.66       679
#
#     accuracy                           0.69      1441
#    macro avg       0.69      0.69      0.69      1441
# weighted avg       0.69      0.69      0.69      1441
#
#
# Genre: Horror
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94      1287
#            1       1.00      0.03      0.05       154
#
#     accuracy                           0.90      1441
#    macro avg       0.95      0.51      0.50      1441
# weighted avg       0.91      0.90      0.85      1441
#
#
# Genre: Fantasy
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      1307
#            1       0.00      0.00      0.00       134
#
#     accuracy                           0.91      1441
#    macro avg       0.45      0.50      0.48      1441
# weighted avg       0.82      0.91      0.86      1441
#
#
# Genre: Music
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1391
#            1       0.00      0.00      0.00        50
#
#     accuracy                           0.97      1441
#    macro avg       0.48      0.50      0.49      1441
# weighted avg       0.93      0.97      0.95      1441
#
#
# Genre: Romance
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      1180
#            1       0.91      0.04      0.07       261
#
#     accuracy                           0.83      1441
#    macro avg       0.87      0.52      0.49      1441
# weighted avg       0.84      0.83      0.75      1441
#
#
# Genre: TV Movie
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1439
#            1       0.00      0.00      0.00         2
#
#     accuracy                           1.00      1441
#    macro avg       0.50      0.50      0.50      1441
# weighted avg       1.00      1.00      1.00      1441
#
#
# Genre: Western
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1412
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.98      1441
#    macro avg       0.49      0.50      0.49      1441
# weighted avg       0.96      0.98      0.97      1441
#
#
# Genre: War
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1394
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.97      1441
#    macro avg       0.48      0.50      0.49      1441
# weighted avg       0.94      0.97      0.95      1441
#
#
# Genre: Science Fiction
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      1273
#            1       1.00      0.07      0.12       168
#
#     accuracy                           0.89      1441
#    macro avg       0.95      0.53      0.53      1441
# weighted avg       0.90      0.89      0.85      1441
#
#
# Genre: Comedy
#               precision    recall  f1-score   support
#
#            0       0.73      0.96      0.83       945
#            1       0.80      0.32      0.46       496
#
#     accuracy                           0.74      1441
#    macro avg       0.76      0.64      0.64      1441
# weighted avg       0.75      0.74      0.70      1441
#
#
# Genre: Crime
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1218
#            1       1.00      0.02      0.04       223
#
#     accuracy                           0.85      1441
#    macro avg       0.92      0.51      0.48      1441
# weighted avg       0.87      0.85      0.78      1441
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\New folder\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
